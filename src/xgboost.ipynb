# %%
from utils import *

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
import folium

import xgboost as xgb

from sklearn.metrics import root_mean_squared_error

# %% [markdown]
# #### Carregando o dataset

# %%
df_train = pd.read_csv('../data/treated_data/train.csv')
df_val = pd.read_csv('../data/treated_data/validation.csv')
df_test = pd.read_csv('../data/treated_data/test.csv')

# %%
df_train.head()
# Out:
#    ponto_id  rssi_1_1  rssi_1_2  rssi_1_3  rssi_2_1  rssi_2_2  rssi_2_3  \
# 0      8790  0.559200  0.398652  0.703014  0.267376  0.426916  0.454187
# 1      3227  0.246700  0.000000  0.332592  0.000000  0.360645  0.342995
# 2      4180  0.184200  0.000000  0.168521  0.145990  0.318269  0.288125
# 3      8922  0.707155  0.446022  0.718534  0.490706  0.361142  0.451422
# 4      1117  0.121940  0.157226  0.161643  0.088497  0.252093  0.256320
#
#    rssi_3_1  rssi_3_2  rssi_3_3   delay_1   delay_2   delay_3       lat  \
# 0  0.317280  0.311331  0.301273  0.333333  0.571429  0.428571 -8.050090
# 1  0.169190  0.339785  0.000000  0.666667  0.428571  0.428571 -8.055834
# 2  0.175386  0.277219  0.000000  0.666667  0.428571  0.285714 -8.055424
# 3  0.326812  0.331300  0.299672  0.166667  0.571429  0.428571 -8.049530
# 4  0.087576  0.252854  0.000000  0.666667  0.428571  0.285714 -8.055380
#
#          lon  indoor
# 0 -34.953120       0
# 1 -34.951362       1
# 2 -34.951597       1
# 3 -34.953290       0
# 4 -34.951736       1

# %%
# Confirmando que não há data leak
assert len(set(df_train['ponto_id']).intersection(set(df_val['ponto_id']))) == 0
assert len(set(df_train['ponto_id']).intersection(set(df_test['ponto_id']))) == 0
assert len(set(df_val['ponto_id']).intersection(set(df_test['ponto_id']))) == 0

# %%
X_train = df_train.drop(['ponto_id', 'indoor', 'lat', 'lon'], axis=1).values
y_train = df_train[['lat', 'lon']].values

X_val = df_val.drop(['ponto_id', 'indoor', 'lat', 'lon'], axis=1).values
y_val = df_val[['lat', 'lon']].values

X_test = df_test.drop(['ponto_id', 'indoor', 'lat', 'lon'], axis=1).values
y_test = df_test[['lat', 'lon']].values

# %% [markdown]
# #### Criando o modelo base

# %%
dtrain = xgb.DMatrix(X_train, label=y_train)
dval = xgb.DMatrix(X_val, label=y_val)
dtest = xgb.DMatrix(X_test, label=y_test)

# %%
params = {
    'max_depth': 5,
    'eta': 0.03,  #Learning Rate
    'objective': 'reg:squarederror', # Problema de regressão
}

# %%
model = xgb.train(
    params,
    dtrain,
    500,
    evals=[(dval, 'validation')],
    early_stopping_rounds=5
)
# Out:
# [0]	validation-rmse:13.04568
# [1]	validation-rmse:12.65440
# [2]	validation-rmse:12.27485
# [3]	validation-rmse:11.90669
# [4]	validation-rmse:11.54956
# [5]	validation-rmse:11.20315
# [6]	validation-rmse:10.86713
# [7]	validation-rmse:10.54119
# [8]	validation-rmse:10.22502
# [9]	validation-rmse:9.91834
# [10]	validation-rmse:9.62085
# [11]	validation-rmse:9.33229
# [12]	validation-rmse:9.05238
# [13]	validation-rmse:8.78087
# [14]	validation-rmse:8.51750
# [15]	validation-rmse:8.26204
# [16]	validation-rmse:8.01423
# [17]	validation-rmse:7.77386
# [18]	validation-rmse:7.54069
# [19]	validation-rmse:7.31452
# [20]	validation-rmse:7.09513
# [21]	validation-rmse:6.88233
# [22]	validation-rmse:6.67590
# [23]	validation-rmse:6.47567
# [24]	validation-rmse:6.28144
# [25]	validation-rmse:6.09304
# [26]	validation-rmse:5.91029
# [27]	validation-rmse:5.73302
# [28]	validation-rmse:5.56107
# [29]	validation-rmse:5.39427
# [30]	validation-rmse:5.23248
# [31]	validation-rmse:5.07554
# [32]	validation-rmse:4.92331
# [33]	validation-rmse:4.77564
# [34]	validation-rmse:4.63241
# [35]	validation-rmse:4.49347
# [36]	validation-rmse:4.35869
# [37]	validation-rmse:4.22796
# [38]	validation-rmse:4.10115
# [39]	validation-rmse:3.97814
# [40]	validation-rmse:3.85883
# [41]	validation-rmse:3.74309
# [42]	validation-rmse:3.63082
# [43]	validation-rmse:3.52192
# [44]	validation-rmse:3.41629
# [45]	validation-rmse:3.31382
# [46]	validation-rmse:3.21443
# [47]	validation-rmse:3.11802
# [48]	validation-rmse:3.02450
# [49]	validation-rmse:2.93379
# [50]	validation-rmse:2.84579
# [51]	validation-rmse:2.76044
# [52]	validation-rmse:2.67765
# [53]	validation-rmse:2.59733
# [54]	validation-rmse:2.51943
# [55]	validation-rmse:2.44387
# [56]	validation-rmse:2.37057
# [57]	validation-rmse:2.29947
# [58]	validation-rmse:2.23050
# [59]	validation-rmse:2.16360
# [60]	validation-rmse:2.09871
# [61]	validation-rmse:2.03576
# [62]	validation-rmse:1.97470
# [63]	validation-rmse:1.91547
# [64]	validation-rmse:1.85803
# [65]	validation-rmse:1.80230
# [66]	validation-rmse:1.74824
# [67]	validation-rmse:1.69581
# [68]	validation-rmse:1.64495
# [69]	validation-rmse:1.59561
# [70]	validation-rmse:1.54775
# [71]	validation-rmse:1.50133
# [72]	validation-rmse:1.45630
# [73]	validation-rmse:1.41263
# [74]	validation-rmse:1.37026
# [75]	validation-rmse:1.32916
# [76]	validation-rmse:1.28929
# [77]	validation-rmse:1.25063
# [78]	validation-rmse:1.21312
# [79]	validation-rmse:1.17673
# [80]	validation-rmse:1.14144
# [81]	validation-rmse:1.10720
# [82]	validation-rmse:1.07400
# [83]	validation-rmse:1.04179
# [84]	validation-rmse:1.01054
# [85]	validation-rmse:0.98023
# [86]	validation-rmse:0.95083
# [87]	validation-rmse:0.92231
# [88]	validation-rmse:0.89465
# [89]	validation-rmse:0.86782
# [90]	validation-rmse:0.84179
# [91]	validation-rmse:0.81655
# [92]	validation-rmse:0.79206
# [93]	validation-rmse:0.76830
# [94]	validation-rmse:0.74526
# [95]	validation-rmse:0.72291
# [96]	validation-rmse:0.70123
# [97]	validation-rmse:0.68020
# [98]	validation-rmse:0.65980
# [99]	validation-rmse:0.64001
# [100]	validation-rmse:0.62081
# [101]	validation-rmse:0.60219
# [102]	validation-rmse:0.58413
# [103]	validation-rmse:0.56661
# [104]	validation-rmse:0.54962
# [105]	validation-rmse:0.53314
# [106]	validation-rmse:0.51715
# [107]	validation-rmse:0.50164
# [108]	validation-rmse:0.48659
# [109]	validation-rmse:0.47200
# [110]	validation-rmse:0.45784
# [111]	validation-rmse:0.44411
# [112]	validation-rmse:0.43079
# [113]	validation-rmse:0.41788
# [114]	validation-rmse:0.40534
# [115]	validation-rmse:0.39319
# [116]	validation-rmse:0.38140
# [117]	validation-rmse:0.36996
# [118]	validation-rmse:0.35886
# [119]	validation-rmse:0.34810
# [120]	validation-rmse:0.33766
# [121]	validation-rmse:0.32754
# [122]	validation-rmse:0.31771
# [123]	validation-rmse:0.30819
# [124]	validation-rmse:0.29894
# [125]	validation-rmse:0.28998
# [126]	validation-rmse:0.28128
# [127]	validation-rmse:0.27285
# [128]	validation-rmse:0.26467
# [129]	validation-rmse:0.25673
# [130]	validation-rmse:0.24903
# [131]	validation-rmse:0.24156
# [132]	validation-rmse:0.23432
# [133]	validation-rmse:0.22729
# [134]	validation-rmse:0.22048
# [135]	validation-rmse:0.21387
# [136]	validation-rmse:0.20745
# [137]	validation-rmse:0.20123
# [138]	validation-rmse:0.19520
# [139]	validation-rmse:0.18935
# [140]	validation-rmse:0.18367
# [141]	validation-rmse:0.17817
# [142]	validation-rmse:0.17282
# [143]	validation-rmse:0.16764
# [144]	validation-rmse:0.16262
# [145]	validation-rmse:0.15774
# [146]	validation-rmse:0.15301
# [147]	validation-rmse:0.14842
# [148]	validation-rmse:0.14397
# [149]	validation-rmse:0.13965
# [150]	validation-rmse:0.13546
# [151]	validation-rmse:0.13140
# [152]	validation-rmse:0.12746
# [153]	validation-rmse:0.12364
# [154]	validation-rmse:0.11993
# [155]	validation-rmse:0.11633
# [156]	validation-rmse:0.11285
# [157]	validation-rmse:0.10946
# [158]	validation-rmse:0.10618
# [159]	validation-rmse:0.10299
# [160]	validation-rmse:0.09991
# [161]	validation-rmse:0.09691
# [162]	validation-rmse:0.09401
# [163]	validation-rmse:0.09119
# [164]	validation-rmse:0.08845
# [165]	validation-rmse:0.08580
# [166]	validation-rmse:0.08323
# [167]	validation-rmse:0.08073
# [168]	validation-rmse:0.07831
# [169]	validation-rmse:0.07596
# [170]	validation-rmse:0.07369
# [171]	validation-rmse:0.07148
# [172]	validation-rmse:0.06933
# [173]	validation-rmse:0.06726
# [174]	validation-rmse:0.06524
# [175]	validation-rmse:0.06328
# [176]	validation-rmse:0.06139
# [177]	validation-rmse:0.05955
# [178]	validation-rmse:0.05776
# [179]	validation-rmse:0.05603
# [180]	validation-rmse:0.05435
# [181]	validation-rmse:0.05272
# [182]	validation-rmse:0.05114
# [183]	validation-rmse:0.04961
# [184]	validation-rmse:0.04812
# [185]	validation-rmse:0.04668
# [186]	validation-rmse:0.04528
# [187]	validation-rmse:0.04392
# [188]	validation-rmse:0.04260
# [189]	validation-rmse:0.04133
# [190]	validation-rmse:0.04009
# [191]	validation-rmse:0.03889
# [192]	validation-rmse:0.03772
# [193]	validation-rmse:0.03659
# [194]	validation-rmse:0.03550
# [195]	validation-rmse:0.03443
# [196]	validation-rmse:0.03340
# [197]	validation-rmse:0.03240
# [198]	validation-rmse:0.03143
# [199]	validation-rmse:0.03049
# [200]	validation-rmse:0.02958
# [201]	validation-rmse:0.02869
# [202]	validation-rmse:0.02783
# [203]	validation-rmse:0.02700
# [204]	validation-rmse:0.02619
# [205]	validation-rmse:0.02540
# [206]	validation-rmse:0.02464
# [207]	validation-rmse:0.02391
# [208]	validation-rmse:0.02319
# [209]	validation-rmse:0.02250
# [210]	validation-rmse:0.02182
# [211]	validation-rmse:0.02117
# [212]	validation-rmse:0.02054
# [213]	validation-rmse:0.01992
# [214]	validation-rmse:0.01933
# [215]	validation-rmse:0.01875
# [216]	validation-rmse:0.01819
# [217]	validation-rmse:0.01765
# [218]	validation-rmse:0.01712
# [219]	validation-rmse:0.01661
# [220]	validation-rmse:0.01611
# [221]	validation-rmse:0.01563
# [222]	validation-rmse:0.01516
# [223]	validation-rmse:0.01471
# [224]	validation-rmse:0.01427
# [225]	validation-rmse:0.01384
# [226]	validation-rmse:0.01343
# [227]	validation-rmse:0.01303
# [228]	validation-rmse:0.01264
# [229]	validation-rmse:0.01226
# [230]	validation-rmse:0.01189
# [231]	validation-rmse:0.01154
# [232]	validation-rmse:0.01119
# [233]	validation-rmse:0.01086
# [234]	validation-rmse:0.01054
# [235]	validation-rmse:0.01022
# [236]	validation-rmse:0.00992
# [237]	validation-rmse:0.00962
# [238]	validation-rmse:0.00933
# [239]	validation-rmse:0.00905
# [240]	validation-rmse:0.00878
# [241]	validation-rmse:0.00852
# [242]	validation-rmse:0.00827
# [243]	validation-rmse:0.00802
# [244]	validation-rmse:0.00778
# [245]	validation-rmse:0.00755
# [246]	validation-rmse:0.00732
# [247]	validation-rmse:0.00710
# [248]	validation-rmse:0.00689
# [249]	validation-rmse:0.00669
# [250]	validation-rmse:0.00649
# [251]	validation-rmse:0.00629
# [252]	validation-rmse:0.00611
# [253]	validation-rmse:0.00593
# [254]	validation-rmse:0.00575
# [255]	validation-rmse:0.00558
# [256]	validation-rmse:0.00541
# [257]	validation-rmse:0.00525
# [258]	validation-rmse:0.00510
# [259]	validation-rmse:0.00494
# [260]	validation-rmse:0.00480
# [261]	validation-rmse:0.00466
# [262]	validation-rmse:0.00452
# [263]	validation-rmse:0.00438
# [264]	validation-rmse:0.00425
# [265]	validation-rmse:0.00413
# [266]	validation-rmse:0.00401
# [267]	validation-rmse:0.00389
# [268]	validation-rmse:0.00377
# [269]	validation-rmse:0.00366
# [270]	validation-rmse:0.00355
# [271]	validation-rmse:0.00345
# [272]	validation-rmse:0.00335
# [273]	validation-rmse:0.00325
# [274]	validation-rmse:0.00315
# [275]	validation-rmse:0.00306
# [276]	validation-rmse:0.00297
# [277]	validation-rmse:0.00288
# [278]	validation-rmse:0.00280
# [279]	validation-rmse:0.00272
# [280]	validation-rmse:0.00264
# [281]	validation-rmse:0.00256
# [282]	validation-rmse:0.00248
# [283]	validation-rmse:0.00241
# [284]	validation-rmse:0.00234
# [285]	validation-rmse:0.00227
# [286]	validation-rmse:0.00221
# [287]	validation-rmse:0.00214
# [288]	validation-rmse:0.00208
# [289]	validation-rmse:0.00202
# [290]	validation-rmse:0.00196
# [291]	validation-rmse:0.00191
# [292]	validation-rmse:0.00185
# [293]	validation-rmse:0.00180
# [294]	validation-rmse:0.00175
# [295]	validation-rmse:0.00170
# [296]	validation-rmse:0.00165
# [297]	validation-rmse:0.00160
# [298]	validation-rmse:0.00156
# [299]	validation-rmse:0.00151
# [300]	validation-rmse:0.00147
# [301]	validation-rmse:0.00143
# [302]	validation-rmse:0.00139
# [303]	validation-rmse:0.00135
# [304]	validation-rmse:0.00131
# [305]	validation-rmse:0.00127
# [306]	validation-rmse:0.00124
# [307]	validation-rmse:0.00120
# [308]	validation-rmse:0.00117
# [309]	validation-rmse:0.00114
# [310]	validation-rmse:0.00111
# [311]	validation-rmse:0.00108
# [312]	validation-rmse:0.00105
# [313]	validation-rmse:0.00102
# [314]	validation-rmse:0.00099
# [315]	validation-rmse:0.00097
# [316]	validation-rmse:0.00094
# [317]	validation-rmse:0.00092
# [318]	validation-rmse:0.00089
# [319]	validation-rmse:0.00087
# [320]	validation-rmse:0.00085
# [321]	validation-rmse:0.00083
# [322]	validation-rmse:0.00080
# [323]	validation-rmse:0.00078
# [324]	validation-rmse:0.00076
# [325]	validation-rmse:0.00075
# [326]	validation-rmse:0.00073
# [327]	validation-rmse:0.00071
# [328]	validation-rmse:0.00069
# [329]	validation-rmse:0.00068
# [330]	validation-rmse:0.00066
# [331]	validation-rmse:0.00064
# [332]	validation-rmse:0.00063
# [333]	validation-rmse:0.00062
# [334]	validation-rmse:0.00060
# [335]	validation-rmse:0.00059
# [336]	validation-rmse:0.00058
# [337]	validation-rmse:0.00056
# [338]	validation-rmse:0.00055
# [339]	validation-rmse:0.00054
# [340]	validation-rmse:0.00053
# [341]	validation-rmse:0.00052
# [342]	validation-rmse:0.00051
# [343]	validation-rmse:0.00050
# [344]	validation-rmse:0.00049
# [345]	validation-rmse:0.00048
# [346]	validation-rmse:0.00047
# [347]	validation-rmse:0.00046
# [348]	validation-rmse:0.00045
# [349]	validation-rmse:0.00044
# [350]	validation-rmse:0.00044
# [351]	validation-rmse:0.00043
# [352]	validation-rmse:0.00042
# [353]	validation-rmse:0.00042
# [354]	validation-rmse:0.00041
# [355]	validation-rmse:0.00040
# [356]	validation-rmse:0.00040
# [357]	validation-rmse:0.00039
# [358]	validation-rmse:0.00039
# [359]	validation-rmse:0.00038
# [360]	validation-rmse:0.00038
# [361]	validation-rmse:0.00037
# [362]	validation-rmse:0.00037
# [363]	validation-rmse:0.00036
# [364]	validation-rmse:0.00036
# [365]	validation-rmse:0.00035
# [366]	validation-rmse:0.00035
# [367]	validation-rmse:0.00035
# [368]	validation-rmse:0.00034
# [369]	validation-rmse:0.00034
# [370]	validation-rmse:0.00034
# [371]	validation-rmse:0.00033
# [372]	validation-rmse:0.00033
# [373]	validation-rmse:0.00033
# [374]	validation-rmse:0.00033
# [375]	validation-rmse:0.00032
# [376]	validation-rmse:0.00032
# [377]	validation-rmse:0.00032
# [378]	validation-rmse:0.00032
# [379]	validation-rmse:0.00032
# [380]	validation-rmse:0.00032
# [381]	validation-rmse:0.00031
# [382]	validation-rmse:0.00031
# [383]	validation-rmse:0.00031
# [384]	validation-rmse:0.00031
# [385]	validation-rmse:0.00031
# [386]	validation-rmse:0.00031
# [387]	validation-rmse:0.00031
# [388]	validation-rmse:0.00030
# [389]	validation-rmse:0.00030
# [390]	validation-rmse:0.00030
# [391]	validation-rmse:0.00030
# [392]	validation-rmse:0.00030
# [393]	validation-rmse:0.00030
# [394]	validation-rmse:0.00030
# [395]	validation-rmse:0.00030
# [396]	validation-rmse:0.00030
# [397]	validation-rmse:0.00029
# [398]	validation-rmse:0.00029
# [399]	validation-rmse:0.00029
# [400]	validation-rmse:0.00029
# [401]	validation-rmse:0.00029
# [402]	validation-rmse:0.00029
# [403]	validation-rmse:0.00029
# [404]	validation-rmse:0.00029
# [405]	validation-rmse:0.00029
# [406]	validation-rmse:0.00029
# [407]	validation-rmse:0.00029
# [408]	validation-rmse:0.00029
# [409]	validation-rmse:0.00029
# [410]	validation-rmse:0.00029
# [411]	validation-rmse:0.00029
# [412]	validation-rmse:0.00029
# [413]	validation-rmse:0.00029
# [414]	validation-rmse:0.00029
# [415]	validation-rmse:0.00029
# [416]	validation-rmse:0.00029
# [417]	validation-rmse:0.00029
# [418]	validation-rmse:0.00029
# [419]	validation-rmse:0.00029
# [420]	validation-rmse:0.00029
# [421]	validation-rmse:0.00029
# [422]	validation-rmse:0.00029
# [423]	validation-rmse:0.00029
# [424]	validation-rmse:0.00029
# [425]	validation-rmse:0.00029
# [426]	validation-rmse:0.00029
# [427]	validation-rmse:0.00029
# [428]	validation-rmse:0.00029
# [429]	validation-rmse:0.00029
# [430]	validation-rmse:0.00029
# [431]	validation-rmse:0.00029
# [432]	validation-rmse:0.00029
# [433]	validation-rmse:0.00029
# [434]	validation-rmse:0.00029
# [435]	validation-rmse:0.00029
# [436]	validation-rmse:0.00029
# [437]	validation-rmse:0.00029
# [438]	validation-rmse:0.00029
# [439]	validation-rmse:0.00029
# [440]	validation-rmse:0.00029
# [441]	validation-rmse:0.00029
# [442]	validation-rmse:0.00029
# [443]	validation-rmse:0.00029
# [444]	validation-rmse:0.00029
# [445]	validation-rmse:0.00029
# [446]	validation-rmse:0.00029
# [447]	validation-rmse:0.00029
# [448]	validation-rmse:0.00029
# [449]	validation-rmse:0.00029

# %% [markdown]
# #### Avaliando o modelo

# %%
y_pred = model.predict(dtest)
rmse = np.sqrt(root_mean_squared_error(y_test, y_pred))
print(f'RMSE: {rmse}')
# Out:
# RMSE: 0.015107480986669388

# %%
map = plot_folium_map(y_test, y_pred)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4680ef07cbcc2e14d66980defced5ea3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div style=&quot;
#         position: fixed;
#         bottom: 50px; left: 50px; width: 150px; height: 90px;
#         border:2px solid grey; z-index:9999; font-size:14px;
#         background-color:white;
#         &quot;&gt;
#         &amp;nbsp;&lt;b&gt;Legenda&lt;/b&gt; &lt;br&gt;
#         &amp;nbsp;&lt;i class=&quot;fa fa-circle&quot; style=&quot;color:red&quot;&gt;&lt;/i&gt;&amp;nbsp;Pontos Preditos&lt;br&gt;
#         &amp;nbsp;&lt;i class=&quot;fa fa-circle&quot; style=&quot;color:blue&quot;&gt;&lt;/i&gt;&amp;nbsp;Pontos Reais
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4680ef07cbcc2e14d66980defced5ea3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4680ef07cbcc2e14d66980defced5ea3 = L.map(
#                 &quot;map_4680ef07cbcc2e14d66980defced5ea3&quot;,
#                 {
#                     center: [-8.05, -34.95],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cd7f35cff9c371b4e95a420ce09c0fcf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_cd7f35cff9c371b4e95a420ce09c0fcf.addTo(map_4680ef07cbcc2e14d66980defced5ea3);
#
#
#             var circle_marker_88eba7877a68d2b56d5eb621086787b1 = L.circleMarker(
#                 [-8.055786, -34.951505],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4680ef07cbcc2e14d66980defced5ea3);
#
#
#             var circle_marker_d78a370471cba4206dfa714f36dbfadd = L.circleMarker(
#                 [-8.055684, -34.951331],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4680ef07cbcc2e14d66980defced5ea3);
#
#
#             var circle_marker_09cfafd3626dd975d133d07ff4fee04c = L.circleMarker(
#                 [-8.055784, -34.951608],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4680ef07cbcc2e14d66980defced5ea3);
#
#
#             var circle_marker_10d32654d82e4fb970db90069d8d5a8f = L.circleMarker(
#                 [-8.055494, -34.951316],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4680ef07cbcc2e14d66980defced5ea3);
#
#
#             var circle_marker_e9e1686aea3d47647560df02d8d64672 = L.circleMarker(
#                 [-8.048160000000001, -34.95909],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4680ef07cbcc2e14d66980defced5ea3);
#
#
#             var circle_marker_8a5baf6417d2edd1072aa601678c6a58 = L.circleMarker(
#                 [-8.05538, -34.951736],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quo

# %% [markdown]
# #### Avaliando o modelos para pontos específicos

# %%
# Prevendo o valor de uma instância específica
idx = 10

X_unit = X_test[idx].reshape(1, -1)
y_unit = np.array([y_test[idx]])
dunit = xgb.DMatrix(X_unit, label=y_unit)
y_pred_unit = model.predict(dunit)

print(f"Pred Point: {y_pred_unit[0]}")
print(f"Real Point: {y_unit[0]}")
# Out:
# Pred Point: [ -8.055453 -34.951557]
# Real Point: [ -8.055424 -34.951597]

# %%
map = plot_folium_map(y_unit, y_pred_unit)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_64ab362e1ff3223bc0e81895de0f37ea {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div style=&quot;
#         position: fixed;
#         bottom: 50px; left: 50px; width: 150px; height: 90px;
#         border:2px solid grey; z-index:9999; font-size:14px;
#         background-color:white;
#         &quot;&gt;
#         &amp;nbsp;&lt;b&gt;Legenda&lt;/b&gt; &lt;br&gt;
#         &amp;nbsp;&lt;i class=&quot;fa fa-circle&quot; style=&quot;color:red&quot;&gt;&lt;/i&gt;&amp;nbsp;Pontos Preditos&lt;br&gt;
#         &amp;nbsp;&lt;i class=&quot;fa fa-circle&quot; style=&quot;color:blue&quot;&gt;&lt;/i&gt;&amp;nbsp;Pontos Reais
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_64ab362e1ff3223bc0e81895de0f37ea&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_64ab362e1ff3223bc0e81895de0f37ea = L.map(
#                 &quot;map_64ab362e1ff3223bc0e81895de0f37ea&quot;,
#                 {
#                     center: [-8.05, -34.95],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_46057a879020fb7cc01a9e9a65695385 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_46057a879020fb7cc01a9e9a65695385.addTo(map_64ab362e1ff3223bc0e81895de0f37ea);
#
#
#             var circle_marker_bd4a6ffef9b9109d01834eda828fb208 = L.circleMarker(
#                 [-8.055424, -34.951597],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_64ab362e1ff3223bc0e81895de0f37ea);
#
#
#             var circle_marker_b02fc31be61a892398b2a7bc17d87bae = L.circleMarker(
#                 [-8.055453300476074, -34.95155715942383],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_64ab362e1ff3223bc0e81895de0f37ea);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
