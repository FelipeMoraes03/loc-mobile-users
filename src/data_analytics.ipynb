# %%
from utils import *

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ### Carregando o Dataset

# %%
df = pd.read_csv('../data/raw_data/data.csv')

# %%
df_train, df_val, df_test = split_data(df)

# %%
df_indoor = df_train[df_train['indoor'] == 1]
df_outdoor = df_train[df_train['indoor'] == 0]

# %% [markdown]
# #### Plotando distribuição dos usuários no conjunto de treino

# %%
plot_distribution_comp(df_train)

# %%
plot_distribution_comp(df_indoor)

# %%
plot_distribution_comp(df_outdoor)

# %%
print(f"Num samples total: {df_train.shape[0]}")
print(f"Num samples indoor: {df_indoor.shape[0]}")
print(f"Num samples outdoor: {df_outdoor.shape[0]}")
# Out:
# Num samples total: 3387
# Num samples indoor: 2305
# Num samples outdoor: 1082

# %%
df_outdoor.shape[0]
# Out:
# 1082

# %%
plot_heat_map(df_outdoor)

# %%
df_outdoor = balance_distribution(df_outdoor)

# %%
df_outdoor.shape[0]
# Out:
# 3960

# %%
plot_heat_map(df_outdoor)

# %%
plot_distribution_comp(df_outdoor)
